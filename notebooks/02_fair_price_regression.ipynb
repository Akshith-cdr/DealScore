# %% [markdown]
# # 02 - Fair Price Regression
#
# This notebook trains regression models to predict fair used-car prices.

# %%
from pathlib import Path
import sys

ROOT_DIR = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.append(str(ROOT_DIR / 'src'))

from train_regression import train_regression_model

best_model, results_df = train_regression_model()
results_df
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_2916/553006867.py in <cell line: 0>()
#       5 sys.path.append(str(ROOT_DIR / 'src'))
#       6
# ----> 7 from train_regression import train_regression_model
#       8
#       9 best_model, results_df = train_regression_model()
#
# ModuleNotFoundError: No module named 'train_regression'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# ## Metric Meaning
#
# - RMSE: Typical prediction error, with bigger mistakes punished more strongly.
# - MAE: Average absolute error in rupees, easier for beginners to understand.
# - R2 Score: How much price variation the model explains. Higher is better.
